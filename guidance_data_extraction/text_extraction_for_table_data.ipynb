# %% [markdown]
# # Text Extractor for Table

# %%
import os
import glob
import pandas
import numpy as np
from bs4 import BeautifulSoup

# %%
guidance_dir = '../guidance_page_collection/guidance_pages_annotated/'
NUM = 59

# %%
output_dir_path = 'extracted_texts/'

# %%
def convert_table_to_text(data_frame):
    results = ''

    if (isinstance(data_frame.columns, pandas.core.indexes.numeric.Int64Index)):
        header = [ data_frame[j][0] for j in data_frame.columns ]
        body_offset = 1
    else:
        header = [ item for item in data_frame.columns ]
        body_offset = 0

    data_header_found = False
    for val in header:
        if (isinstance(val, np.floating)): continue 
        if (isinstance(val, tuple)): continue
        if (val.lower().find('[[[{dat}category]]]') > -1 or
            val.lower().find('[[[{dat}data category]]]') > -1 or  # 47
            val.lower().find('[[[{dat}play category]]]') > -1 or  # 27
            val.lower().find('[[[{dat}data]]]') > -1 or 
            val.lower().find('[[[{dat}data type]]]') > -1 or  # 9, 19, 37, 43
            val.lower().find('[[[{dat}data types]]]') > -1 or 
            val.lower().find('[[[{dat}datapoint]]]') > -1 or 
            val.lower().find('[[[{pra}collected]]]') > -1 or 
            val.lower().find('[[[{pur}purpose]]]') > -1 or
            val.lower().find('[[[{pur}data purpose]]]') > -1 or
            val.lower().find('[[[{pur}data collection purpose]]]') > -1  # 44
           ):
            data_header_found = True
            break
    if (data_header_found):
        for i in range(body_offset, len(data_frame)):
            for j in range(len(data_frame.columns)):
                if (data_frame[data_frame.columns[j]][i] == '' or
                    isinstance(data_frame[data_frame.columns[j]][i], float)
                   ):
                    continue
                results += f'{header[j]}, {data_frame[data_frame.columns[j]][i]}. '
            results = results.rstrip(' ').rstrip(',').rstrip('.')+'.\n'
    else:
        print(f'Header not detected: {header = }')
        for val in header:
            results += f'{val} '
        results = results.rstrip(' ').rstrip('.')+'.\n'
        for i in range(body_offset, len(data_frame)):
            for j in range(len(data_frame.columns)):
                results += f'{data_frame[data_frame.columns[j]][i]} '
            results = results.rstrip(' ').rstrip(',').rstrip('.')+'.\n'

    return results

# %%
def load_data_frames_from_html(target):
    html_file_path = f'{guidance_dir}{target}.html'

    if (not os.path.isfile(html_file_path)):
        print(f'HTML source not found for {target = }')
        return

    html_content = open(html_file_path, 'r').read()
    print(f'{len(html_content) = }')
    soup = BeautifulSoup(html_content, 'html.parser')
    for th in soup.find_all('th'):
        if (th.parent.name == 'div'):
            th.parent.unwrap()

    for th in soup.find_all('td'):
        for li in th.find_all('li'):
            li.string = li.text.rstrip() + '.'
            # print(li.string)
    try:
        data_frames = pandas.read_html(str(soup))
    except ValueError:
        print('No tables found')
        return

    return data_frames

# %%
def analyze(guidance):
    results = ''

    data_frames = load_data_frames_from_html(guidance)

    if (data_frames):
        print(f'#tables = {len(data_frames)}')
    else:
        return

    for data_frame in data_frames:
        # print(data_frame)
        results += convert_table_to_text(data_frame)

    with open(f'{output_dir_path}{guidance}_tab.txt', 'w') as f:
        f.write(results)

# %%
for target in range(1, NUM + 1):
    print(f'{target = }')
    analyze(target)

print('Done')
# Out:
# target = 1
# len(html_content) = 15109
# No tables found
# target = 2
# len(html_content) = 81960
# #tables = 14
# target = 3
# len(html_content) = 22284
# No tables found
# target = 4
# len(html_content) = 253256
# #tables = 2
# Header not detected: header = ['Question', 'Developer Response']
# target = 5
# len(html_content) = 213377
# #tables = 15
# Header not detected: header = ['Does your app collect or share any of the required user data types?', 'Yes']
# target = 6
# len(html_content) = 127070
# #tables = 1
# target = 7
# len(html_content) = 94173
# #tables = 1
# target = 8
# len(html_content) = 90527
# #tables = 1
# target = 9
# len(html_content) = 56877
# #tables = 1
# target = 10
# len(html_content) = 256010
# #tables = 2
# target = 11
# len(html_content) = 131390
# #tables = 2
# Header not detected: header = ['Action', 'Details']
# target = 12
# len(html_content) = 65625
# #tables = 1
# target = 13
# len(html_content) = 407279
# #tables = 13
# Header not detected: header = ['Privacy Manager Flag', 'Features']
# Header not detected: header = ['Data', 'Description', 'Privacy Manager Features']
# Header not detected: header = ['Data', 'Description', 'Privacy Manager Features']
# Header not detected: header = ['Privacy Manager Flag', 'Kotlin Constant', 'AirshipConfig Value']
# Header not detected: header = ['Privacy Manager Flag', 'Java Constant', 'AirshipConfig Value']
# Header not detected: header = ['Privacy Manager Flag', 'Swift Constant', 'AirshipConfig Value']
# Header not detected: header = ['Privacy Manager Flag', 'Objective-C Constant', 'AirshipConfig Value']
# Header not detected: header = ['Privacy Manager Flag', 'JS Constant']
# Header not detected: header = ['Privacy Manager Flag', 'String Feature Name', 'AirshipConfig Value']
# Header not detected: header = ['Privacy Manager Flag', 'JS Constant']
# Header not detected: header = ['Privacy Manager Flag', 'C# Constant', 'AirshipConfig Value']
# Header not detected: header = ['Privacy Manager Flag', 'JS Constant']
# Header not detected: header = ['Privacy Manager Flag', 'String Feature Name']
# target = 14
# len(html_content) = 39961
# #tables = 2
# target = 15
# len(html_content) = 503040
# #tables = 16
# Header not detected: header = ['Event Type', 'Retention', 'Description']
# Header not detected: header = ['Attribute name', 'Type', 'Description']
# Header not detected: header = ['Attribute name', 'Type', 'Description']
# Header not detected: header = ['Attribute name', 'Type', 'Description']
# Header not detected: header = ['Fullname', 'Type', 'Description']
# Header not detected: header = ['Attribute name', 'Type', 'Description']
# Header not detected: header = ['Metric', 'Type', 'Description']
# Header not detected: header = ['Attribute name', 'Type', 'Description']
# Header not detected: header = ['Metric', 'Type', 'Description']
# Header not detected: header = ['Attribute name', 'Type', 'Description']
# Header not detected: header = ['Metric', 'Type', 'Description']
# Header not detected: header = ['Attribute', 'Type', 'Description']
# Header not detected: header = ['Attribute', 'Type', 'Description']
# Header not detected: header = ['Attribute', 'Type', 'Description']
# Header not detected: header = ['Metric', 'Type', 'Description']
# Header not detected: header = ['Attribute', 'Type', 'Description']
# target = 16
# len(html_content) = 321614
# #tables = 1
# target = 17
# len(html_content) = 90019
# No tables found
# target = 18
# len(html_content) = 193382
# #tables = 1
# target = 19
# len(html_content) = 67049
# #tables = 1
# target = 20
# len(html_content) = 225221
# #tables = 15
# Header not detected: header = ['Does the SDK collect or share any of the required user data types?', 'Yes']
# target = 21
# len(html_content) = 259517
# #tables = 2
# Header not detected: header = ['[[[{ENC}Does your SDK encrypt data in transit?]]]', '[[[{ENC}Yes]]]']
# target = 22
# len(html_content) = 34652
# No tables found
# target = 23
# len(html_content) = 277961
# #tables = 26
# Header not detected: header = ['[[[{ENC}Data encryption]]]', '[[[{ENC}For the collected end-user data listed on this page, Firebase  encrypts the data in transit using HTTPS]]].']
# target = 24
# len(html_content) = 198698
# #tables = 2
# Header not detected: header = ['Unnamed: 0', '[[[{PUR}Data used by Adjust?]]]']
# target = 25
# len(html_content) = 456800
# #tables = 3
# Header not detected: header = ['Question', 'Answer']
# Header not detected: header = ['Question', 'Answer']
# target = 26
# len(html_content) = 99017
# #tables = 1
# Header not detected: header = ['Contact Info', '✘']
# target = 27
# len(html_content) = 85620
# #tables = 13
# Header not detected: header = ['Question', 'Answer', 'Why']
# target = 28
# len(html_content) = 64194
# No tables found
# target = 29
# len(html_content) = 350232
# #tables = 5
# Header not detected: header = ['userId String,optional', 'The database ID for this user.']
# Header not detected: header = ['name String,required', 'A name for the tracked action.']
# Header not detected: header = ['category String,optional*', 'A category for the screen. Optional if name is provided.']
# Header not detected: header = ['userId String,required', 'The database ID for this user.']
# Header not detected: header = ['newId String,required', 'The new ID to track this user with.']
# target = 30
# len(html_content) = 264840
# #tables = 8
# Header not detected: header = ['お客様の便宜を図るため、本ページの翻訳版をご用意しております。翻訳版は情報提供のみを目的としており、本ページは英語版が正式なものとなります。']
# Header not detected: header = ['呼称', '意味', 'STRIPE での使用例']
# Header not detected: header = ['ユーザーの所在地', '処理の目的', 'STRIPE 法人の名称', 'STRIPE 法人の所在地']
# Header not detected: header = ['収集する個人情報の種類', '過去 12 か月間の事業目的での開示実績', 'データの開示先']
# Header not detected: header = ['処理の目的', '個人データの種類', '法的根拠']
# Header not detected: header = ['処理の目的', '個人データの種類', '法的根拠']
# Header not detected: header = ['処理の目的', '個人データの種類', '法的根拠']
# Header not detected: header = ['処理の目的', '個人データの種類', '法的根拠']
# target = 31
# len(html_content) = 490552
# #tables = 2
# target = 32
# len(html_content) = 1048901
# #tables = 2
# target = 33
# len(html_content) = 142050
# #tables = 5
# target = 34
# len(html_content) = 92968
# #tables = 1
# target = 35
# len(html_content) = 109994
# No tables found
# target = 36
# len(html_content) = 206086
# #tables = 2
# Header not detected: header = ['Exception Code', 'Description']
# target = 37
# len(html_content) = 209337
# #tables = 3
# Header not detected: header = ['Data encryption', '[[[{ENC}For the collected end-user data listed on this page, HyBid Android SDK encrypts the data in transit using HTTPS]]].']
# target = 38
# len(html_content) = 47428
# No tables found
# target = 39
# len(html_content) = 204308
# No tables found
# target = 40
# len(html_content) = 318897
# #tables = 2
# Header not detected: header = ['Questions', 'Answers for Braze SDK']
# target = 41
# len(html_content) = 65268
# #tables = 2
# Header not detected: header = ['Does Pangle collect or share any of the required user data types?', 'Yes']
# target = 42
# len(html_content) = 66451
# #tables = 15
# Header not detected: header = ['Question', 'Answer', 'Comments']
# target = 43
# len(html_content) = 169025
# #tables = 3
# Header not detected: header = ['Data encryption', '[[[{ENC}For the collected end-user data listed on this page, Smaato NextGen SDK encrypts the data in transit using HTTPS]]].']
# target = 44
# len(html_content) = 2009326
# #tables = 38
# Header not detected: header = ['Libraries and SDKs', "If your app has libraries or SDKs that transmit data from the user's device, specify this regardless of where the information is sent: to you or to a third-party server."]
# Header not detected: header = ['Libraries and SDKs', "If your app has libraries or SDKs that transmit data from the user's device, specify this regardless of where the information is sent: to you or to a third-party server."]
# Header not detected: header = ['Off-device transmission (between servers)', 'For example, user data collected in the app is transmitted from your server to a third-party server.']
# Header not detected: header = ['Off-device transmission (between servers)', 'For example, user data collected in the app is transmitted from your server to a third-party server.']
# Header not detected: header = ['[[[{ENC}Encryption during transmission]]]', "[[[{ENC}Specify whether data is encrypted when transmitted from the end user's device to the server. Some apps enable users to send data to third-party sites or services. For example, a messaging app may have the function to send an SMS via a mobile operator that uses other encryption methods. Then the data safety section will indicate that information is transmitted between the user's device and the app servers over a secure connection]]]."]
# Header not detected: header = ['[[[{ENC}Encryption during transmission]]]', "[[[{ENC}Specify whether data is encrypted when transmitted from the end user's device to the server. Some apps enable users to send data to third-party sites or services. For example, a messaging app may have the function to send an SMS via a mobile operator that uses other encryption methods. Then the data safety section will indicate that information is transmitted between the user's device and the app servers over a secure connection]]]."]
# Header not detected: header = ['[[[{DAT}Location]]]', '[[[{DAT}Location]]].1', '[[[{DAT}Location]]].2']
# Header not detected: header = ['[[[{DAT}Location]]]', '[[[{DAT}Location]]].1', '[[[{DAT}Location]]].2']
# Header not detected: header = ['[[[{DAT}Personal information]]]', '[[[{DAT}Personal information]]].1', '[[[{DAT}Personal information]]].2']
# Header not detected: header = ['[[[{DAT}Personal information]]]', '[[[{DAT}Personal information]]].1', '[[[{DAT}Personal information]]].2']
# Header not detected: header = ['[[[{DAT}Financial data]]]', '[[[{DAT}Financial data]]].1', '[[[{DAT}Financial data]]].2']
# Header not detected: header = ['[[[{DAT}Financial data]]]', '[[[{DAT}Financial data]]].1', '[[[{DAT}Financial data]]].2']
# Header not detected: header = ['[[[{DAT}Health and physical activity]]]', '[[[{DAT}Health and physical activity]]].1', '[[[{DAT}Health and physical activity]]].2']
# Header not detected: header = ['[[[{DAT}Health and physical activity]]]', '[[[{DAT}Health and physical activity]]].1', '[[[{DAT}Health and physical activity]]].2']
# Header not detected: header = ['[[[{DAT}Messages]]]', '[[[{DAT}Messages]]].1', '[[[{DAT}Messages]]].2']
# Header not detected: header = ['[[[{DAT}Messages]]]', '[[[{DAT}Messages]]].1', '[[[{DAT}Messages]]].2']
# Header not detected: header = ['[[[{DAT}Photos and videos]]]', '[[[{DAT}Photos and videos]]].1', '[[[{DAT}Photos and videos]]].2']
# Header not detected: header = ['[[[{DAT}Photos and videos]]]', '[[[{DAT}Photos and videos]]].1', '[[[{DAT}Photos and videos]]].2']
# Header not detected: header = ['[[[{DAT}Audio files]]]', '[[[{DAT}Audio files]]].1', '[[[{DAT}Audio files]]].2']
# Header not detected: header = ['[[[{DAT}Audio files]]]', '[[[{DAT}Audio files]]].1', '[[[{DAT}Audio files]]].2']
# Header not detected: header = ['[[[{DAT}Files and documents]]]', '[[[{DAT}Files and documents]]].1', '[[[{DAT}Files and documents]]].2']
# Header not detected: header = ['[[[{DAT}Files and documents]]]', '[[[{DAT}Files and documents]]].1', '[[[{DAT}Files and documents]]].2']
# Header not detected: header = ['[[[{DAT}Calendar]]]', '[[[{DAT}Calendar]]].1', '[[[{DAT}Calendar]]].2']
# Header not detected: header = ['[[[{DAT}Calendar]]]', '[[[{DAT}Calendar]]].1', '[[[{DAT}Calendar]]].2']
# Header not detected: header = ['[[[{DAT}Contacts]]]', '[[[{DAT}Contacts]]].1', '[[[{DAT}Contacts]]].2']
# Header not detected: header = ['[[[{DAT}Contacts]]]', '[[[{DAT}Contacts]]].1', '[[[{DAT}Contacts]]].2']
# Header not detected: header = ['[[[{DAT}History of actions in the app]]]', '[[[{DAT}History of actions in the app]]].1', '[[[{DAT}History of actions in the app]]].2']
# Header not detected: header = ['[[[{DAT}History of actions in the app]]]', '[[[{DAT}History of actions in the app]]].1', '[[[{DAT}History of actions in the app]]].2']
# Header not detected: header = ['[[[{DAT}Information about browsing the internet]]]', '[[[{DAT}Information about browsing the internet]]].1', '[[[{DAT}Information about browsing the internet]]].2']
# Header not detected: header = ['[[[{DAT}Information about browsing the internet]]]', '[[[{DAT}Information about browsing the internet]]].1', '[[[{DAT}Information about browsing the internet]]].2']
# Header not detected: header = ['[[[{DAT}Information about the app and its operation]]]', '[[[{DAT}Information about the app and its operation]]].1', '[[[{DAT}Information about the app and its operation]]].2']
# Header not detected: header = ['[[[{DAT}Information about the app and its operation]]]', '[[[{DAT}Information about the app and its operation]]].1', '[[[{DAT}Information about the app and its operation]]].2']
# Header not detected: header = ['[[[{DAT}Device IDs or other IDs]]]', '[[[{DAT}Device IDs or other IDs]]].1', '[[[{DAT}Device IDs or other IDs]]].2']
# Header not detected: header = ['[[[{DAT}Device IDs or other IDs]]]', '[[[{DAT}Device IDs or other IDs]]].1', '[[[{DAT}Device IDs or other IDs]]].2']
# target = 45
# len(html_content) = 212143
# #tables = 15
# Header not detected: header = ['Does your app collect or share any of the required user data types?', 'Yes']
# target = 46
# len(html_content) = 154322
# No tables found
# target = 47
# len(html_content) = 371772
# #tables = 1
# target = 48
# len(html_content) = 88470
# #tables = 2
# Header not detected: header = [('[[[{DAT}Data type]]]', '[[[{DAT}Location]]]', '[[[{DAT}Personal info]]]', '[[[{DAT}Financial info]]]', '[[[{DAT}Health and fitness]]]', '[[[{DAT}Messages]]]', '[[[{DAT}Photos or videos]]]', '[[[{DAT}Audio files]]]', '[[[{DAT}Files and docs]]]', '[[[{DAT}Calendar]]]', '[[[{DAT}Contacts]]]', '[[[{DAT}App activity]]]', '[[[{DAT}Web browsing]]]', '[[[{DAT}App info and performance]]]', '[[[{DAT}Device or other IDs]]]'), ('[[[{PRA}MyTracker data collection (default configuration)]]]', '[[[{DAT}Location]]]', '[[[{DAT}Personal info]]]', '[[[{DAT}Financial info]]]', '[[[{DAT}Health and fitness]]]', '[[[{DAT}Messages]]]', '[[[{DAT}Photos or videos]]]', '[[[{DAT}Audio files]]]', '[[[{DAT}Files and docs]]]', '[[[{DAT}Calendar]]]', '[[[{DAT}Contacts]]]', '[[[{DAT}App activity]]]', '[[[{DAT}Web browsing]]]', '[[[{DAT}App info and performance]]]', '[[[{DAT}Device or other IDs]]]'), ('Comment', '[[[{DAT}Location]]]', '[[[{DAT}Personal info]]]', '[[[{DAT}Financial info]]]', '[[[{DAT}Health and fitness]]]', '[[[{DAT}Messages]]]', '[[[{DAT}Photos or videos]]]', '[[[{DAT}Audio files]]]', '[[[{DAT}Files and docs]]]', '[[[{DAT}Calendar]]]', '[[[{DAT}Contacts]]]', '[[[{DAT}App activity]]]', '[[[{DAT}Web browsing]]]', '[[[{DAT}App info and performance]]]', '[[[{DAT}Device or other IDs]]]')]
# target = 49
# len(html_content) = 23833
# #tables = 2
# Header not detected: header = ['Does the SDK collect or share any of the required user data types?', '[[[{ENC}Is all of the data collected by the SDK encrypted in transit?]]]', '[[[{DEL}Does the SDK provide a way for users to request that their data is deleted?]]]']
# target = 50
# len(html_content) = 291390
# #tables = 1
# target = 51
# len(html_content) = 79610
# #tables = 3
# Header not detected: header = ['Does your app collect or share any of the required user data types?  Select  Yes  ..', nan]
# Header not detected: header = ['[[[{DAT}Location]]]  [[[{PRA}Select:]]]  [[[{DAT}Approximate Location]]].  [[[{DAT}Precise Location]]].', nan]
# Header not detected: header = ['[[[{DAT}Name, Email address, Address & Phone Number]]]  [[[{PRA}Select the following:  Collected]]].  [[[{EPH}Yes, this collected data is processed ephemerally]]].  [[[{PRA}Users can choose whether this data is collected]]].  [[[{PUR}App Functionality.  Personalization]]].  [[[{PUR}NOTE: If contests are run in the app and used for further marketing purposes, you should also select: Advertising or marketing]]].', nan]
# target = 52
# len(html_content) = 58314
# #tables = 2
# Header not detected: header = ['Questions', 'Answers related to Batch SDK']
# target = 53
# len(html_content) = 46188
# #tables = 1
# target = 54
# len(html_content) = 176894
# #tables = 2
# Header not detected: header = ['Question', 'Developer Response']
# target = 55
# len(html_content) = 63668
# #tables = 1
# target = 56
# len(html_content) = 506386
# #tables = 6
# target = 57
# len(html_content) = 83052
# #tables = 1
# target = 58
# len(html_content) = 62987
# #tables = 2
# Header not detected: header = ['[[[{ENC}Data encryption]]]', '[[[{ENC}For the collected end-user data listed on this page, Flurry encrypts the data in transit using HTTPS]]].']
# target = 59
# len(html_content) = 33277
# No tables found
# Done
